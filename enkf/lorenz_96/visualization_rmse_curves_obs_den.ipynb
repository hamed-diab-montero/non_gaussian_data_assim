# %%
import numpy as np
import matplotlib.pylab as plt
import matplotlib
import os

# %% [markdown]
# # EnKF

# %% [markdown]
# # Stationary

# %%
folder_stationary_enkf='/home/hamed/Data Assimilation Methods/enkf/lorenz_96/stationary/results_rmse/'

num_iter=10
num_tsteps=6000

obs_den_stationary_01=1
obs_den_stationary_02=2
obs_den_stationary_03=3

rmse_l96_stationary_obs_den_01=np.zeros((num_tsteps,2,num_iter))
rmse_l96_stationary_obs_den_02=np.zeros((num_tsteps,2,num_iter))
rmse_l96_stationary_obs_den_03=np.zeros((num_tsteps,2,num_iter))

for i in range(num_iter):
    
    filename_stationary_enkf_obs_den_01=os.path.join(folder_stationary_enkf,'rmse_l96_stationary_obs_den_'+str(obs_den_stationary_01).zfill(2)+'_run_'+str(i+1).zfill(2)+'.txt')
    filename_stationary_enkf_obs_den_02=os.path.join(folder_stationary_enkf,'rmse_l96_stationary_obs_den_'+str(obs_den_stationary_02).zfill(2)+'_run_'+str(i+1).zfill(2)+'.txt')
    filename_stationary_enkf_obs_den_03=os.path.join(folder_stationary_enkf,'rmse_l96_stationary_obs_den_'+str(obs_den_stationary_03).zfill(2)+'_run_'+str(i+1).zfill(2)+'.txt')
   
    rmse_l96_stationary_obs_den_01[:,:,i]=np.genfromtxt(filename_stationary_enkf_obs_den_01)
    rmse_l96_stationary_obs_den_02[:,:,i]=np.genfromtxt(filename_stationary_enkf_obs_den_02)
    rmse_l96_stationary_obs_den_03[:,:,i]=np.genfromtxt(filename_stationary_enkf_obs_den_03)
    
#     rmse_l96_stationary_obs_den_01.append(rmse_l96_stationary_01)
#     rmse_l96_stationary_obs_den_02.append(rmse_l96_stationary_02)
#     rmse_l96_stationary_obs_den_03.append(rmse_l96_stationary_03)

# %%
for i in range(num_iter):
    plt.plot(rmse_l96_stationary_obs_den_01[:,0,0],rmse_l96_stationary_obs_den_01[:,1,i],color='lightgray')
plt.plot(rmse_l96_stationary_obs_den_01[:,0,0],np.mean(rmse_l96_stationary_obs_den_01[:,1,:],axis=1),color='gray')

for i in range(num_iter):
    plt.plot(rmse_l96_stationary_obs_den_02[:,0,0],rmse_l96_stationary_obs_den_02[:,1,i],color='lightblue')
plt.plot(rmse_l96_stationary_obs_den_02[:,0,0],np.mean(rmse_l96_stationary_obs_den_02[:,1,:],axis=1),color='blue')
    
for i in range(num_iter):
    plt.plot(rmse_l96_stationary_obs_den_03[:,0,0],rmse_l96_stationary_obs_den_03[:,1,i],color='lightgreen')
plt.plot(rmse_l96_stationary_obs_den_03[:,0,0],np.mean(rmse_l96_stationary_obs_den_03[:,1,:],axis=1),color='green')
    
plt.ylim(0,3.5)
plt.xlim(10,60)
# Out:
# (10.0, 60.0)

# %% [markdown]
# # Periodic

# %%
folder_periodic_enkf='/home/hamed/Data Assimilation Methods/enkf/lorenz_96/periodic/results_rmse/'

num_iter=10
num_tsteps=6000

obs_den_periodic_01=1
obs_den_periodic_02=2
obs_den_periodic_05=5

rmse_l96_periodic_obs_den_01=np.zeros((num_tsteps,2,num_iter))
rmse_l96_periodic_obs_den_02=np.zeros((num_tsteps,2,num_iter))
rmse_l96_periodic_obs_den_05=np.zeros((num_tsteps,2,num_iter))

for i in range(num_iter):
    
    filename_periodic_enkf_obs_den_01=os.path.join(folder_periodic_enkf,'rmse_l96_periodic_obs_den_'+str(obs_den_periodic_01).zfill(2)+'_run_'+str(i+1).zfill(2)+'.txt')
    filename_periodic_enkf_obs_den_02=os.path.join(folder_periodic_enkf,'rmse_l96_periodic_obs_den_'+str(obs_den_periodic_02).zfill(2)+'_run_'+str(i+1).zfill(2)+'.txt')
    filename_periodic_enkf_obs_den_05=os.path.join(folder_periodic_enkf,'rmse_l96_periodic_obs_den_'+str(obs_den_periodic_05).zfill(2)+'_run_'+str(i+1).zfill(2)+'.txt')
   
    rmse_l96_periodic_obs_den_01[:,:,i]=np.genfromtxt(filename_periodic_enkf_obs_den_01)
    rmse_l96_periodic_obs_den_02[:,:,i]=np.genfromtxt(filename_periodic_enkf_obs_den_02)
    rmse_l96_periodic_obs_den_05[:,:,i]=np.genfromtxt(filename_periodic_enkf_obs_den_05)
    
#     rmse_l96_periodic_obs_den_01.append(rmse_l96_periodic_01)
#     rmse_l96_periodic_obs_den_02.append(rmse_l96_periodic_02)
#     rmse_l96_periodic_obs_den_05.append(rmse_l96_periodic_05)

# %%
for i in range(num_iter):
    plt.plot(rmse_l96_periodic_obs_den_01[:,0,0],rmse_l96_periodic_obs_den_01[:,1,i],color='lightgray')
plt.plot(rmse_l96_periodic_obs_den_01[:,0,0],np.mean(rmse_l96_periodic_obs_den_01[:,1,:],axis=1),color='gray')

for i in range(num_iter):
    plt.plot(rmse_l96_periodic_obs_den_02[:,0,0],rmse_l96_periodic_obs_den_02[:,1,i],color='lightblue')
plt.plot(rmse_l96_periodic_obs_den_02[:,0,0],np.mean(rmse_l96_periodic_obs_den_02[:,1,:],axis=1),color='blue')
    
for i in range(num_iter):
    plt.plot(rmse_l96_periodic_obs_den_05[:,0,0],rmse_l96_periodic_obs_den_05[:,1,i],color='lightgreen')
plt.plot(rmse_l96_periodic_obs_den_05[:,0,0],np.mean(rmse_l96_periodic_obs_den_05[:,1,:],axis=1),color='green')
    
plt.ylim(0,3.5)
plt.xlim(10,60)
# Out:
# (10.0, 60.0)

# %% [markdown]
# # Chaotic

# %%
folder_chaos_enkf='/home/hamed/Data Assimilation Methods/enkf/lorenz_96/chaos/results_rmse/'

num_iter=10
num_tsteps=6000

obs_den_chaos_01=1
obs_den_chaos_02=2
obs_den_chaos_08=8

rmse_l96_chaos_obs_den_01=np.zeros((num_tsteps,2,num_iter))
rmse_l96_chaos_obs_den_02=np.zeros((num_tsteps,2,num_iter))
rmse_l96_chaos_obs_den_08=np.zeros((num_tsteps,2,num_iter))

for i in range(num_iter):
    
    filename_chaos_enkf_obs_den_01=os.path.join(folder_chaos_enkf,'rmse_l96_chaotic_obs_den_'+str(obs_den_chaos_01).zfill(2)+'_run_'+str(i+1).zfill(2)+'.txt')
    filename_chaos_enkf_obs_den_02=os.path.join(folder_chaos_enkf,'rmse_l96_chaotic_obs_den_'+str(obs_den_chaos_02).zfill(2)+'_run_'+str(i+1).zfill(2)+'.txt')
    filename_chaos_enkf_obs_den_08=os.path.join(folder_chaos_enkf,'rmse_l96_chaotic_obs_den_'+str(obs_den_chaos_08).zfill(2)+'_run_'+str(i+1).zfill(2)+'.txt')
   
    rmse_l96_chaos_obs_den_01[:,:,i]=np.genfromtxt(filename_chaos_enkf_obs_den_01)
    rmse_l96_chaos_obs_den_02[:,:,i]=np.genfromtxt(filename_chaos_enkf_obs_den_02)
    rmse_l96_chaos_obs_den_08[:,:,i]=np.genfromtxt(filename_chaos_enkf_obs_den_08)
    
#     rmse_l96_chaos_obs_den_01.append(rmse_l96_chaos_01)
#     rmse_l96_chaos_obs_den_02.append(rmse_l96_chaos_02)
#     rmse_l96_chaos_obs_den_08.append(rmse_l96_chaos_08)

# %%
for i in range(num_iter):
    plt.plot(rmse_l96_chaos_obs_den_01[:,0,0],rmse_l96_chaos_obs_den_01[:,1,i],color='lightgray')
plt.plot(rmse_l96_chaos_obs_den_01[:,0,0],np.mean(rmse_l96_chaos_obs_den_01[:,1,:],axis=1),color='gray')

for i in range(num_iter):
    plt.plot(rmse_l96_chaos_obs_den_02[:,0,0],rmse_l96_chaos_obs_den_02[:,1,i],color='lightblue')
plt.plot(rmse_l96_chaos_obs_den_02[:,0,0],np.mean(rmse_l96_chaos_obs_den_02[:,1,:],axis=1),color='blue')
    
for i in range(num_iter):
    plt.plot(rmse_l96_chaos_obs_den_08[:,0,0],rmse_l96_chaos_obs_den_08[:,1,i],color='lightgreen')
plt.plot(rmse_l96_chaos_obs_den_08[:,0,0],np.mean(rmse_l96_chaos_obs_den_08[:,1,:],axis=1),color='green')
    
plt.ylim(0,3.5)
plt.xlim(10,60)
# Out:
# (10.0, 60.0)

# %% [markdown]
# # Comparison

# %%
matplotlib.rc('xtick', labelsize=25) 
matplotlib.rc('ytick', labelsize=25)

# %%
fig=plt.figure(figsize=(20,10))
#
#  PERIODIC
#

for i in range(num_iter):
    plt.plot(rmse_l96_periodic_obs_den_01[:,0,0],rmse_l96_periodic_obs_den_01[:,1,i],color='turquoise',linewidth=3,alpha=0.3)
plt.plot(rmse_l96_periodic_obs_den_01[:,0,0],np.mean(rmse_l96_periodic_obs_den_01[:,1,:],axis=1),color='teal',linewidth=3,linestyle='--')

for i in range(num_iter):
    plt.plot(rmse_l96_periodic_obs_den_02[:,0,0],rmse_l96_periodic_obs_den_02[:,1,i],color='mediumorchid',linewidth=3,alpha=0.3)
plt.plot(rmse_l96_periodic_obs_den_02[:,0,0],np.mean(rmse_l96_periodic_obs_den_02[:,1,:],axis=1),color='purple',linewidth=3,linestyle='--')
    
for i in range(num_iter):
    plt.plot(rmse_l96_periodic_obs_den_05[:,0,0],rmse_l96_periodic_obs_den_05[:,1,i],color='goldenrod',linewidth=3,alpha=0.3)
plt.plot(rmse_l96_periodic_obs_den_05[:,0,0],np.mean(rmse_l96_periodic_obs_den_05[:,1,:],axis=1),color='darkgoldenrod',linewidth=3,linestyle='--')
    
plt.ylim(0,3.5)
plt.xlim(10,55)


#
#  CHAOS
#

for i in range(num_iter):
    plt.plot(rmse_l96_chaos_obs_den_01[:,0,0],rmse_l96_chaos_obs_den_01[:,1,i],color='turquoise',linewidth=3,alpha=0.3)
plt.plot(rmse_l96_chaos_obs_den_01[:,0,0],np.mean(rmse_l96_chaos_obs_den_01[:,1,:],axis=1),color='teal',linewidth=3)

for i in range(num_iter):
    plt.plot(rmse_l96_chaos_obs_den_02[:,0,0],rmse_l96_chaos_obs_den_02[:,1,i],color='mediumorchid',linewidth=3,alpha=0.3)
plt.plot(rmse_l96_chaos_obs_den_02[:,0,0],np.mean(rmse_l96_chaos_obs_den_02[:,1,:],axis=1),color='purple',linewidth=3)
    
for i in range(num_iter):
    plt.plot(rmse_l96_chaos_obs_den_08[:,0,0],rmse_l96_chaos_obs_den_08[:,1,i],color='goldenrod',linewidth=3,alpha=0.3)
plt.plot(rmse_l96_chaos_obs_den_08[:,0,0],np.mean(rmse_l96_chaos_obs_den_08[:,1,:],axis=1),color='darkgoldenrod',linewidth=3)
    
plt.ylim(0,3.5)
plt.xlim(10,55)

plt.hlines(y=1,xmin=10,xmax=60,color='r',linewidth=3)

plt.ylabel('RMSE',fontweight='bold',fontsize=20)
plt.xlabel('Time (yr)',fontweight='bold',fontsize=20)
# Out:
# Text(0.5, 0, 'Time (yr)')

# %% [markdown]
# # AGSM

# %% [markdown]
# # Periodic

# %%
folder_periodic_agsm='/home/hamed/Data Assimilation Methods/agsm/lorenz_96/periodic/results_rmse/'

num_iter=10

obs_den_periodic_01=1
obs_den_periodic_02=2
obs_den_periodic_05=5

rmse_l96_periodic_obs_den_01=[]
rmse_l96_periodic_obs_den_02=[]
rmse_l96_periodic_obs_den_05=[]

for i in range(num_iter):
    
    filename_periodic_agsm_obs_den_01=os.path.join(folder_periodic_agsm,'rmse_l96_periodic_obs_den_'+str(obs_den_periodic_01).zfill(2)+'_run_'+str(i+1).zfill(2)+'.txt')
    filename_periodic_agsm_obs_den_02=os.path.join(folder_periodic_agsm,'rmse_l96_periodic_obs_den_'+str(obs_den_periodic_02).zfill(2)+'_run_'+str(i+1).zfill(2)+'.txt')
    filename_periodic_agsm_obs_den_05=os.path.join(folder_periodic_agsm,'rmse_l96_periodic_obs_den_'+str(obs_den_periodic_05).zfill(2)+'_run_'+str(i+1).zfill(2)+'.txt')
   
    rmse_l96_periodic_01=np.genfromtxt(filename_periodic_agsm_obs_den_01)
    rmse_l96_periodic_02=np.genfromtxt(filename_periodic_agsm_obs_den_02)
    rmse_l96_periodic_05=np.genfromtxt(filename_periodic_agsm_obs_den_05)
    
    rmse_l96_periodic_obs_den_01.append(rmse_l96_periodic_01)
    rmse_l96_periodic_obs_den_02.append(rmse_l96_periodic_02)
    rmse_l96_periodic_obs_den_05.append(rmse_l96_periodic_05)

# %%
folder_periodic_agsm='/home/hamed/Data Assimilation Methods/agsm/lorenz_96/periodic/results_rmse/'

num_iter=10
num_tsteps=4949

obs_den_periodic_01=1
obs_den_periodic_02=2
obs_den_periodic_05=5

rmse_l96_periodic_obs_den_01=np.zeros((num_tsteps,2,num_iter))
rmse_l96_periodic_obs_den_02=np.zeros((num_tsteps,2,num_iter))
rmse_l96_periodic_obs_den_05=np.zeros((num_tsteps,2,num_iter))

for i in range(num_iter):
    
    filename_periodic_agsm_obs_den_01=os.path.join(folder_periodic_agsm,'rmse_l96_periodic_obs_den_'+str(obs_den_periodic_01).zfill(2)+'_run_'+str(i+1).zfill(2)+'.txt')
    filename_periodic_agsm_obs_den_02=os.path.join(folder_periodic_agsm,'rmse_l96_periodic_obs_den_'+str(obs_den_periodic_02).zfill(2)+'_run_'+str(i+1).zfill(2)+'.txt')
    filename_periodic_agsm_obs_den_05=os.path.join(folder_periodic_agsm,'rmse_l96_periodic_obs_den_'+str(obs_den_periodic_05).zfill(2)+'_run_'+str(i+1).zfill(2)+'.txt')
   
    rmse_l96_periodic_obs_den_01[:,:,i]=np.genfromtxt(filename_periodic_agsm_obs_den_01)
    rmse_l96_periodic_obs_den_02[:,:,i]=np.genfromtxt(filename_periodic_agsm_obs_den_02)
    rmse_l96_periodic_obs_den_05[:,:,i]=np.genfromtxt(filename_periodic_agsm_obs_den_05)
    
#     rmse_l96_periodic_obs_den_01.append(rmse_l96_periodic_01)
#     rmse_l96_periodic_obs_den_02.append(rmse_l96_periodic_02)
#     rmse_l96_periodic_obs_den_05.append(rmse_l96_periodic_05)

# %%
for i in range(num_iter):
    plt.plot(rmse_l96_periodic_obs_den_01[:,0,0],rmse_l96_periodic_obs_den_01[:,1,i],color='lightgray')
plt.plot(rmse_l96_periodic_obs_den_01[:,0,0],np.mean(rmse_l96_periodic_obs_den_01[:,1,:],axis=1),color='gray')

for i in range(num_iter):
    plt.plot(rmse_l96_periodic_obs_den_02[:,0,0],rmse_l96_periodic_obs_den_02[:,1,i],color='lightblue')
plt.plot(rmse_l96_periodic_obs_den_02[:,0,0],np.mean(rmse_l96_periodic_obs_den_02[:,1,:],axis=1),color='blue')
    
for i in range(num_iter):
    plt.plot(rmse_l96_periodic_obs_den_05[:,0,0],rmse_l96_periodic_obs_den_05[:,1,i],color='lightgreen')
plt.plot(rmse_l96_periodic_obs_den_05[:,0,0],np.mean(rmse_l96_periodic_obs_den_05[:,1,:],axis=1),color='green')
    
plt.ylim(0,3.5)
plt.xlim(10,60)
# Out:
# (10.0, 60.0)

# %% [markdown]
# # Chaos

# %%
folder_chaos_agsm='/home/hamed/Data Assimilation Methods/agsm/lorenz_96/chaos/results_rmse/'

num_iter=10
num_tsteps=4949

obs_den_chaos_01=1
obs_den_chaos_02=2
obs_den_chaos_08=8

rmse_l96_chaos_obs_den_01=np.zeros((num_tsteps,2,num_iter))
rmse_l96_chaos_obs_den_02=np.zeros((num_tsteps,2,num_iter))
rmse_l96_chaos_obs_den_08=np.zeros((num_tsteps,2,num_iter))

for i in range(num_iter):
    
    filename_chaos_agsm_obs_den_01=os.path.join(folder_chaos_agsm,'rmse_l96_chaotic_obs_den_'+str(obs_den_chaos_01).zfill(2)+'_run_'+str(i+1).zfill(2)+'.txt')
    filename_chaos_agsm_obs_den_02=os.path.join(folder_chaos_agsm,'rmse_l96_chaotic_obs_den_'+str(obs_den_chaos_02).zfill(2)+'_run_'+str(i+1).zfill(2)+'.txt')
    filename_chaos_agsm_obs_den_08=os.path.join(folder_chaos_agsm,'rmse_l96_chaotic_obs_den_'+str(obs_den_chaos_08).zfill(2)+'_run_'+str(i+1).zfill(2)+'.txt')
   
    rmse_l96_chaos_obs_den_01[:,:,i]=np.genfromtxt(filename_chaos_agsm_obs_den_01)
    rmse_l96_chaos_obs_den_02[:,:,i]=np.genfromtxt(filename_chaos_agsm_obs_den_02)
    rmse_l96_chaos_obs_den_08[:,:,i]=np.genfromtxt(filename_chaos_agsm_obs_den_08)
    
#     rmse_l96_chaos_obs_den_01.append(rmse_l96_chaos_01)
#     rmse_l96_chaos_obs_den_02.append(rmse_l96_chaos_02)
#     rmse_l96_chaos_obs_den_08.append(rmse_l96_chaos_08)

# %%
for i in range(num_iter):
    plt.plot(rmse_l96_chaos_obs_den_01[:,0,0],rmse_l96_chaos_obs_den_01[:,1,i],color='lightgray')
plt.plot(rmse_l96_chaos_obs_den_01[:,0,0],np.mean(rmse_l96_chaos_obs_den_01[:,1,:],axis=1),color='gray')

for i in range(num_iter):
    plt.plot(rmse_l96_chaos_obs_den_02[:,0,0],rmse_l96_chaos_obs_den_02[:,1,i],color='lightblue')
plt.plot(rmse_l96_chaos_obs_den_02[:,0,0],np.mean(rmse_l96_chaos_obs_den_02[:,1,:],axis=1),color='blue')
    
for i in range(num_iter):
    plt.plot(rmse_l96_chaos_obs_den_08[:,0,0],rmse_l96_chaos_obs_den_08[:,1,i],color='lightgreen')
plt.plot(rmse_l96_chaos_obs_den_08[:,0,0],np.mean(rmse_l96_chaos_obs_den_08[:,1,:],axis=1),color='green')
    
plt.ylim(0,3.5)
plt.xlim(10,60)
# Out:
# (10.0, 60.0)

# %%
fig=plt.figure(figsize=(20,10))
#
#  PERIODIC
#

for i in range(num_iter):
    plt.plot(rmse_l96_periodic_obs_den_01[:,0,0],rmse_l96_periodic_obs_den_01[:,1,i],color='turquoise',linewidth=3,alpha=0.3)
plt.plot(rmse_l96_periodic_obs_den_01[:,0,0],np.mean(rmse_l96_periodic_obs_den_01[:,1,:],axis=1),color='teal',linewidth=3,linestyle='--')

for i in range(num_iter):
    plt.plot(rmse_l96_periodic_obs_den_02[:,0,0],rmse_l96_periodic_obs_den_02[:,1,i],color='mediumorchid',linewidth=3,alpha=0.3)
plt.plot(rmse_l96_periodic_obs_den_02[:,0,0],np.mean(rmse_l96_periodic_obs_den_02[:,1,:],axis=1),color='purple',linewidth=3,linestyle='--')
    
for i in range(num_iter):
    plt.plot(rmse_l96_periodic_obs_den_05[:,0,0],rmse_l96_periodic_obs_den_05[:,1,i],color='goldenrod',linewidth=3,alpha=0.3)
plt.plot(rmse_l96_periodic_obs_den_05[:,0,0],np.mean(rmse_l96_periodic_obs_den_05[:,1,:],axis=1),color='darkgoldenrod',linewidth=3,linestyle='--')
    
plt.ylim(0,3.5)
plt.xlim(10,55)


#
#  CHAOS
#

for i in range(num_iter):
    plt.plot(rmse_l96_chaos_obs_den_01[:,0,0],rmse_l96_chaos_obs_den_01[:,1,i],color='turquoise',linewidth=3,alpha=0.3)
plt.plot(rmse_l96_chaos_obs_den_01[:,0,0],np.mean(rmse_l96_chaos_obs_den_01[:,1,:],axis=1),color='teal',linewidth=3)

for i in range(num_iter):
    plt.plot(rmse_l96_chaos_obs_den_02[:,0,0],rmse_l96_chaos_obs_den_02[:,1,i],color='mediumorchid',linewidth=3,alpha=0.3)
plt.plot(rmse_l96_chaos_obs_den_02[:,0,0],np.mean(rmse_l96_chaos_obs_den_02[:,1,:],axis=1),color='purple',linewidth=3)
    
for i in range(num_iter):
    plt.plot(rmse_l96_chaos_obs_den_08[:,0,0],rmse_l96_chaos_obs_den_08[:,1,i],color='goldenrod',linewidth=3,alpha=0.3)
plt.plot(rmse_l96_chaos_obs_den_08[:,0,0],np.mean(rmse_l96_chaos_obs_den_08[:,1,:],axis=1),color='darkgoldenrod',linewidth=3)
    
plt.ylim(0,3.5)
plt.xlim(10,55)

plt.hlines(y=1,xmin=10,xmax=60,color='r',linewidth=3)

plt.ylabel('RMSE',fontweight='bold',fontsize=20)
plt.xlabel('Time (yr)',fontweight='bold',fontsize=20)
# Out:
# Text(0.5, 0, 'Time (yr)')

# %% [markdown]
# # PFF

# %% [markdown]
# # Periodic

# %%
folder_periodic_pff='/home/hamed/Data Assimilation Methods/pff/lorenz_96/periodic/results_rmse/'

num_iter=5
num_tsteps=6000

obs_den_periodic_01=1
# obs_den_periodic_02=2
# obs_den_periodic_05=5

rmse_l96_periodic_obs_den_01=np.zeros((num_tsteps,2,num_iter))
# rmse_l96_periodic_obs_den_02=np.zeros((num_tsteps,2,num_iter))
# rmse_l96_periodic_obs_den_05=np.zeros((num_tsteps,2,num_iter))

for i in range(num_iter):
    
    filename_periodic_pff_obs_den_01=os.path.join(folder_periodic_pff,'rmse_l96_periodic_obs_den_'+str(obs_den_periodic_01).zfill(2)+'_run_'+str(i+1).zfill(2)+'.txt')
#     filename_periodic_pff_obs_den_02=os.path.join(folder_periodic_pff,'rmse_l96_periodic_obs_den_'+str(obs_den_periodic_02).zfill(2)+'_run_'+str(i+1).zfill(2)+'.txt')
#     filename_periodic_pff_obs_den_05=os.path.join(folder_periodic_pff,'rmse_l96_periodic_obs_den_'+str(obs_den_periodic_05).zfill(2)+'_run_'+str(i+1).zfill(2)+'.txt')
   
    rmse_l96_periodic_obs_den_01[:,:,i]=np.genfromtxt(filename_periodic_pff_obs_den_01)
#     rmse_l96_periodic_obs_den_02[:,:,i]=np.genfromtxt(filename_periodic_pff_obs_den_02)
#     rmse_l96_periodic_obs_den_05[:,:,i]=np.genfromtxt(filename_periodic_pff_obs_den_05)
    
#     rmse_l96_periodic_obs_den_01.append(rmse_l96_periodic_01)
#     rmse_l96_periodic_obs_den_02.append(rmse_l96_periodic_02)
#     rmse_l96_periodic_obs_den_05.append(rmse_l96_periodic_05)
#     rmse_l96_periodic_obs_den_05.append(rmse_l96_periodic_05)

# %%
for i in range(num_iter):
    plt.plot(rmse_l96_periodic_obs_den_01[:,0,0],rmse_l96_periodic_obs_den_01[:,1,i],color='lightgray')
plt.plot(rmse_l96_periodic_obs_den_01[:,0,0],np.mean(rmse_l96_periodic_obs_den_01[:,1,:],axis=1),color='gray')

# for i in range(num_iter):
#     plt.plot(rmse_l96_periodic_obs_den_02[:,0,0],rmse_l96_periodic_obs_den_02[:,1,i],color='lightblue')
# plt.plot(rmse_l96_periodic_obs_den_02[:,0,0],np.mean(rmse_l96_periodic_obs_den_02[:,1,:],axis=1),color='blue')
    
# for i in range(num_iter):
#     plt.plot(rmse_l96_periodic_obs_den_05[:,0,0],rmse_l96_periodic_obs_den_05[:,1,i],color='lightgreen')
# plt.plot(rmse_l96_periodic_obs_den_05[:,0,0],np.mean(rmse_l96_periodic_obs_den_05[:,1,:],axis=1),color='green')
    
plt.ylim(0,3.5)
plt.xlim(10,60)
# Out:
# (10.0, 60.0)

# %% [markdown]
# # Chaos

# %%
folder_chaos_pff='/home/hamed/Data Assimilation Methods/pff/lorenz_96/chaos/results_rmse/'

num_iter=5
num_tsteps=6000

obs_den_chaos_01=1
obs_den_chaos_02=2
obs_den_chaos_08=8

rmse_l96_chaos_obs_den_01=np.zeros((num_tsteps,2,num_iter))
rmse_l96_chaos_obs_den_02=np.zeros((num_tsteps,2,num_iter))
rmse_l96_chaos_obs_den_08=np.zeros((num_tsteps,2,num_iter))

for i in range(num_iter):
    
    filename_chaos_pff_obs_den_01=os.path.join(folder_chaos_pff,'rmse_l96_chaotic_obs_den_'+str(obs_den_chaos_01).zfill(2)+'_run_'+str(i+1).zfill(2)+'.txt')
    filename_chaos_pff_obs_den_02=os.path.join(folder_chaos_pff,'rmse_l96_chaotic_obs_den_'+str(obs_den_chaos_02).zfill(2)+'_run_'+str(i+1).zfill(2)+'.txt')
    filename_chaos_pff_obs_den_08=os.path.join(folder_chaos_pff,'rmse_l96_chaotic_obs_den_'+str(obs_den_chaos_08).zfill(2)+'_run_'+str(i+1).zfill(2)+'.txt')
   
    rmse_l96_chaos_obs_den_01[:,:,i]=np.genfromtxt(filename_chaos_pff_obs_den_01)
    rmse_l96_chaos_obs_den_02[:,:,i]=np.genfromtxt(filename_chaos_pff_obs_den_02)
    rmse_l96_chaos_obs_den_08[:,:,i]=np.genfromtxt(filename_chaos_pff_obs_den_08)
    
#     rmse_l96_chaos_obs_den_01.append(rmse_l96_chaos_01)
#     rmse_l96_chaos_obs_den_02.append(rmse_l96_chaos_02)
#     rmse_l96_chaos_obs_den_08.append(rmse_l96_chaos_08)
#     rmse_l96_chaos_obs_den_08.append(rmse_l96_chaos_08)

# %%
for i in range(num_iter):
    plt.plot(rmse_l96_chaos_obs_den_01[:,0,0],rmse_l96_chaos_obs_den_01[:,1,i],color='lightgray')
plt.plot(rmse_l96_chaos_obs_den_01[:,0,0],np.mean(rmse_l96_chaos_obs_den_01[:,1,:],axis=1),color='gray')

for i in range(num_iter):
    plt.plot(rmse_l96_chaos_obs_den_02[:,0,0],rmse_l96_chaos_obs_den_02[:,1,i],color='lightblue')
plt.plot(rmse_l96_chaos_obs_den_02[:,0,0],np.mean(rmse_l96_chaos_obs_den_02[:,1,:],axis=1),color='blue')
    
for i in range(num_iter):
    plt.plot(rmse_l96_chaos_obs_den_08[:,0,0],rmse_l96_chaos_obs_den_08[:,1,i],color='lightgreen')
plt.plot(rmse_l96_chaos_obs_den_08[:,0,0],np.mean(rmse_l96_chaos_obs_den_08[:,1,:],axis=1),color='green')
    
plt.ylim(0,3.5)
plt.xlim(10,60)
# Out:
# (10.0, 60.0)

# %%
fig=plt.figure(figsize=(20,10))
#
#  PERIODIC
#

for i in range(num_iter):
    plt.plot(rmse_l96_periodic_obs_den_01[:,0,0],rmse_l96_periodic_obs_den_01[:,1,i],color='turquoise',linewidth=3,alpha=0.3)
plt.plot(rmse_l96_periodic_obs_den_01[:,0,0],np.mean(rmse_l96_periodic_obs_den_01[:,1,:],axis=1),color='teal',linewidth=3,linestyle='--')

# for i in range(num_iter):
#     plt.plot(rmse_l96_periodic_obs_den_02[:,0,0],rmse_l96_periodic_obs_den_02[:,1,i],color='mediumorchid',linewidth=3,alpha=0.3)
# plt.plot(rmse_l96_periodic_obs_den_02[:,0,0],np.mean(rmse_l96_periodic_obs_den_02[:,1,:],axis=1),color='purple',linewidth=3,linestyle='--')
    
# for i in range(num_iter):
#     plt.plot(rmse_l96_periodic_obs_den_05[:,0,0],rmse_l96_periodic_obs_den_05[:,1,i],color='goldenrod',linewidth=3,alpha=0.3)
# plt.plot(rmse_l96_periodic_obs_den_05[:,0,0],np.mean(rmse_l96_periodic_obs_den_05[:,1,:],axis=1),color='darkgoldenrod',linewidth=3,linestyle='--')
    
plt.ylim(0,3.5)
plt.xlim(10,55)


#
#  CHAOS
#

for i in range(num_iter):
    plt.plot(rmse_l96_chaos_obs_den_01[:,0,0],rmse_l96_chaos_obs_den_01[:,1,i],color='turquoise',linewidth=3,alpha=0.3)
plt.plot(rmse_l96_chaos_obs_den_01[:,0,0],np.mean(rmse_l96_chaos_obs_den_01[:,1,:],axis=1),color='teal',linewidth=3)

for i in range(num_iter):
    plt.plot(rmse_l96_chaos_obs_den_02[:,0,0],rmse_l96_chaos_obs_den_02[:,1,i],color='mediumorchid',linewidth=3,alpha=0.3)
plt.plot(rmse_l96_chaos_obs_den_02[:,0,0],np.mean(rmse_l96_chaos_obs_den_02[:,1,:],axis=1),color='purple',linewidth=3)
    
for i in range(num_iter):
    plt.plot(rmse_l96_chaos_obs_den_08[:,0,0],rmse_l96_chaos_obs_den_08[:,1,i],color='goldenrod',linewidth=3,alpha=0.3)
plt.plot(rmse_l96_chaos_obs_den_08[:,0,0],np.mean(rmse_l96_chaos_obs_den_08[:,1,:],axis=1),color='darkgoldenrod',linewidth=3)
    
plt.ylim(0,3.5)
plt.xlim(10,55)

plt.hlines(y=1,xmin=10,xmax=60,color='r',linewidth=3)

plt.ylabel('RMSE',fontweight='bold',fontsize=20)
plt.xlabel('Time (yr)',fontweight='bold',fontsize=20)
# Out:
# Text(0.5, 0, 'Time (yr)')

# %%
matplotlib.rc('xtick', labelsize=25) 
matplotlib.rc('ytick', labelsize=25)
