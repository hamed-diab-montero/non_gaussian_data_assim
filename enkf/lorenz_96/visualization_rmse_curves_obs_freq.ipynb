# %%
import numpy as np
import matplotlib.pylab as plt
import matplotlib
import os

# %% [markdown]
# # ENKF

# %% [markdown]
# # Periodic

# %%
folder_periodic_enkf='/home/hamed/Data Assimilation Methods/enkf/lorenz_96/periodic_obs_freq/results_rmse/'

num_iter=10
num_tsteps=6000

obs_freq_periodic_01=1
obs_freq_periodic_02=2
obs_freq_periodic_03=3
obs_freq_periodic_04=4
obs_freq_periodic_05=5
obs_freq_periodic_06=6
obs_freq_periodic_07=7

rmse_l96_periodic_obs_freq_01=np.zeros((num_tsteps,2,num_iter))
rmse_l96_periodic_obs_freq_02=np.zeros((num_tsteps,2,num_iter))
rmse_l96_periodic_obs_freq_03=np.zeros((num_tsteps,2,num_iter))
rmse_l96_periodic_obs_freq_04=np.zeros((num_tsteps,2,num_iter))
rmse_l96_periodic_obs_freq_05=np.zeros((num_tsteps,2,num_iter))
rmse_l96_periodic_obs_freq_06=np.zeros((num_tsteps,2,num_iter))
rmse_l96_periodic_obs_freq_07=np.zeros((num_tsteps,2,num_iter))

for i in range(num_iter):
    
    filename_periodic_enkf_obs_freq_01=os.path.join(folder_periodic_enkf,'rmse_l96_periodic_obs_freq_'+str(obs_freq_periodic_01).zfill(2)+'_run_'+str(i+1).zfill(2)+'.txt')
    filename_periodic_enkf_obs_freq_02=os.path.join(folder_periodic_enkf,'rmse_l96_periodic_obs_freq_'+str(obs_freq_periodic_02).zfill(2)+'_run_'+str(i+1).zfill(2)+'.txt')
    filename_periodic_enkf_obs_freq_03=os.path.join(folder_periodic_enkf,'rmse_l96_periodic_obs_freq_'+str(obs_freq_periodic_03).zfill(2)+'_run_'+str(i+1).zfill(2)+'.txt')
    filename_periodic_enkf_obs_freq_04=os.path.join(folder_periodic_enkf,'rmse_l96_periodic_obs_freq_'+str(obs_freq_periodic_04).zfill(2)+'_run_'+str(i+1).zfill(2)+'.txt')
    filename_periodic_enkf_obs_freq_05=os.path.join(folder_periodic_enkf,'rmse_l96_periodic_obs_freq_'+str(obs_freq_periodic_05).zfill(2)+'_run_'+str(i+1).zfill(2)+'.txt')
    filename_periodic_enkf_obs_freq_06=os.path.join(folder_periodic_enkf,'rmse_l96_periodic_obs_freq_'+str(obs_freq_periodic_06).zfill(2)+'_run_'+str(i+1).zfill(2)+'.txt')
    filename_periodic_enkf_obs_freq_07=os.path.join(folder_periodic_enkf,'rmse_l96_periodic_obs_freq_'+str(obs_freq_periodic_07).zfill(2)+'_run_'+str(i+1).zfill(2)+'.txt')
    
    rmse_l96_periodic_obs_freq_01[:,:,i]=np.genfromtxt(filename_periodic_enkf_obs_freq_01)
    rmse_l96_periodic_obs_freq_02[:,:,i]=np.genfromtxt(filename_periodic_enkf_obs_freq_02)
    rmse_l96_periodic_obs_freq_03[:,:,i]=np.genfromtxt(filename_periodic_enkf_obs_freq_03)
    rmse_l96_periodic_obs_freq_04[:,:,i]=np.genfromtxt(filename_periodic_enkf_obs_freq_04)
    rmse_l96_periodic_obs_freq_05[:,:,i]=np.genfromtxt(filename_periodic_enkf_obs_freq_05)
    rmse_l96_periodic_obs_freq_06[:,:,i]=np.genfromtxt(filename_periodic_enkf_obs_freq_06)
    rmse_l96_periodic_obs_freq_07[:,:,i]=np.genfromtxt(filename_periodic_enkf_obs_freq_07)
    
    
#     rmse_l96_periodic_obs_freq_01.append(rmse_l96_periodic_01)
#     rmse_l96_periodic_obs_freq_02.append(rmse_l96_periodic_02)
#     rmse_l96_periodic_obs_freq_05.append(rmse_l96_periodic_05)

# %%
fig=plt.figure(figsize=(20,10))

# for i in range(num_iter):
#     plt.plot(rmse_l96_periodic_obs_freq_01[:,0,0],rmse_l96_periodic_obs_freq_01[:,1,i],color='gray',alpha=0.3)
plt.plot(rmse_l96_periodic_obs_freq_01[:,0,0],np.mean(rmse_l96_periodic_obs_freq_01[:,1,:],axis=1),color='gray')

# for i in range(num_iter):
#     plt.plot(rmse_l96_periodic_obs_freq_02[:,0,0],rmse_l96_periodic_obs_freq_02[:,1,i],color='blue',alpha=0.3)
plt.plot(rmse_l96_periodic_obs_freq_02[:,0,0],np.mean(rmse_l96_periodic_obs_freq_02[:,1,:],axis=1),color='blue')
    
# for i in range(num_iter):
#     plt.plot(rmse_l96_periodic_obs_freq_03[:,0,0],rmse_l96_periodic_obs_freq_03[:,1,i],color='green',alpha=0.3)
plt.plot(rmse_l96_periodic_obs_freq_03[:,0,0],np.mean(rmse_l96_periodic_obs_freq_03[:,1,:],axis=1),color='green')
    
# for i in range(num_iter):
#     plt.plot(rmse_l96_periodic_obs_freq_04[:,0,0],rmse_l96_periodic_obs_freq_04[:,1,i],color='red',alpha=0.3)
plt.plot(rmse_l96_periodic_obs_freq_04[:,0,0],np.mean(rmse_l96_periodic_obs_freq_04[:,1,:],axis=1),color='red')

# for i in range(num_iter):
#     plt.plot(rmse_l96_periodic_obs_freq_05[:,0,0],rmse_l96_periodic_obs_freq_05[:,1,i],color='m',alpha=0.3)
plt.plot(rmse_l96_periodic_obs_freq_05[:,0,0],np.mean(rmse_l96_periodic_obs_freq_05[:,1,:],axis=1),color='m')
    
# for i in range(num_iter):
#     plt.plot(rmse_l96_periodic_obs_freq_06[:,0,0],rmse_l96_periodic_obs_freq_06[:,1,i],color='k',alpha=0.3)
plt.plot(rmse_l96_periodic_obs_freq_06[:,0,0],np.mean(rmse_l96_periodic_obs_freq_06[:,1,:],axis=1),color='k')
   
# for i in range(num_iter):
#     plt.plot(rmse_l96_periodic_obs_freq_07[:,0,0],rmse_l96_periodic_obs_freq_07[:,1,i],color='brown',alpha=0.3)
plt.plot(rmse_l96_periodic_obs_freq_07[:,0,0],np.mean(rmse_l96_periodic_obs_freq_07[:,1,:],axis=1),color='brown')
  
    
plt.ylim(0,3.0)    
# plt.ylim(0,1.0)
plt.xlim(10,55)
# Out:
# (10.0, 55.0)

# %% [markdown]
# # Chaos

# %%
folder_chaos_enkf='/home/hamed/Data Assimilation Methods/enkf/lorenz_96/chaos_obs_freq/results_rmse/'

num_iter=10
num_tsteps_01=6000
num_tsteps_02=6000
num_tsteps_03=6000
num_tsteps_04=4899
num_tsteps_05=4799
num_tsteps_06=4699
num_tsteps_07=4499

obs_freq_chaos_01=1
obs_freq_chaos_02=2
obs_freq_chaos_03=3
obs_freq_chaos_04=4
obs_freq_chaos_05=5
obs_freq_chaos_06=6
obs_freq_chaos_07=7

rmse_l96_chaos_obs_freq_01=np.zeros((num_tsteps_01,2,num_iter))
rmse_l96_chaos_obs_freq_02=np.zeros((num_tsteps_02,2,num_iter))
rmse_l96_chaos_obs_freq_03=np.zeros((num_tsteps_03,2,num_iter))
rmse_l96_chaos_obs_freq_04=np.zeros((num_tsteps_04,2,num_iter))
rmse_l96_chaos_obs_freq_05=np.zeros((num_tsteps_05,2,num_iter))
rmse_l96_chaos_obs_freq_06=np.zeros((num_tsteps_06,2,num_iter))
rmse_l96_chaos_obs_freq_07=np.zeros((num_tsteps_07,2,num_iter))

for i in range(num_iter):
    
    filename_chaos_enkf_obs_freq_01=os.path.join(folder_chaos_enkf,'rmse_l96_chaotic_obs_freq_'+str(obs_freq_chaos_01).zfill(2)+'_run_'+str(i+1).zfill(2)+'.txt')
    filename_chaos_enkf_obs_freq_02=os.path.join(folder_chaos_enkf,'rmse_l96_chaotic_obs_freq_'+str(obs_freq_chaos_02).zfill(2)+'_run_'+str(i+1).zfill(2)+'.txt')
    filename_chaos_enkf_obs_freq_03=os.path.join(folder_chaos_enkf,'rmse_l96_chaotic_obs_freq_'+str(obs_freq_chaos_03).zfill(2)+'_run_'+str(i+1).zfill(2)+'.txt')
    filename_chaos_enkf_obs_freq_04=os.path.join(folder_chaos_enkf,'rmse_l96_chaotic_obs_freq_'+str(obs_freq_chaos_04).zfill(2)+'_run_'+str(i+1).zfill(2)+'.txt')
    filename_chaos_enkf_obs_freq_05=os.path.join(folder_chaos_enkf,'rmse_l96_chaotic_obs_freq_'+str(obs_freq_chaos_05).zfill(2)+'_run_'+str(i+1).zfill(2)+'.txt')
    filename_chaos_enkf_obs_freq_06=os.path.join(folder_chaos_enkf,'rmse_l96_chaotic_obs_freq_'+str(obs_freq_chaos_06).zfill(2)+'_run_'+str(i+1).zfill(2)+'.txt')
    filename_chaos_enkf_obs_freq_07=os.path.join(folder_chaos_enkf,'rmse_l96_chaotic_obs_freq_'+str(obs_freq_chaos_07).zfill(2)+'_run_'+str(i+1).zfill(2)+'.txt')
    
    rmse_l96_chaos_obs_freq_01[:,:,i]=np.genfromtxt(filename_chaos_enkf_obs_freq_01)
    rmse_l96_chaos_obs_freq_02[:,:,i]=np.genfromtxt(filename_chaos_enkf_obs_freq_02)
    rmse_l96_chaos_obs_freq_03[:,:,i]=np.genfromtxt(filename_chaos_enkf_obs_freq_03)
    rmse_l96_chaos_obs_freq_04[:,:,i]=np.genfromtxt(filename_chaos_enkf_obs_freq_04)
    rmse_l96_chaos_obs_freq_05[:,:,i]=np.genfromtxt(filename_chaos_enkf_obs_freq_05)
    rmse_l96_chaos_obs_freq_06[:,:,i]=np.genfromtxt(filename_chaos_enkf_obs_freq_06)
    rmse_l96_chaos_obs_freq_07[:,:,i]=np.genfromtxt(filename_chaos_enkf_obs_freq_07)
    
    
#     rmse_l96_chaos_obs_freq_01.append(rmse_l96_chaos_01)
#     rmse_l96_chaos_obs_freq_02.append(rmse_l96_chaos_02)
#     rmse_l96_chaos_obs_freq_05.append(rmse_l96_chaos_05)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_6541/4257716996.py in <module>
#      39     rmse_l96_chaos_obs_freq_02[:,:,i]=np.genfromtxt(filename_chaos_enkf_obs_freq_02)
#      40     rmse_l96_chaos_obs_freq_03[:,:,i]=np.genfromtxt(filename_chaos_enkf_obs_freq_03)
# ---> 41     rmse_l96_chaos_obs_freq_04[:,:,i]=np.genfromtxt(filename_chaos_enkf_obs_freq_04)
#      42     rmse_l96_chaos_obs_freq_05[:,:,i]=np.genfromtxt(filename_chaos_enkf_obs_freq_05)
#      43     rmse_l96_chaos_obs_freq_06[:,:,i]=np.genfromtxt(filename_chaos_enkf_obs_freq_06)
#
# ValueError: could not broadcast input array from shape (6000,2) into shape (4899,2)

# %%
fig=plt.figure(figsize=(20,10))

# for i in range(num_iter):
#     plt.plot(rmse_l96_chaos_obs_freq_01[:,0,0],rmse_l96_chaos_obs_freq_01[:,1,i],color='gray',alpha=0.3)
plt.plot(rmse_l96_chaos_obs_freq_01[:,0,0],np.mean(rmse_l96_chaos_obs_freq_01[:,1,:],axis=1),color='gray')

# for i in range(num_iter):
#     plt.plot(rmse_l96_chaos_obs_freq_02[:,0,0],rmse_l96_chaos_obs_freq_02[:,1,i],color='blue',alpha=0.3)
plt.plot(rmse_l96_chaos_obs_freq_02[:,0,0],np.mean(rmse_l96_chaos_obs_freq_02[:,1,:],axis=1),color='blue')
    
# for i in range(num_iter):
#     plt.plot(rmse_l96_chaos_obs_freq_03[:,0,0],rmse_l96_chaos_obs_freq_03[:,1,i],color='green',alpha=0.3)
plt.plot(rmse_l96_chaos_obs_freq_03[:,0,0],np.mean(rmse_l96_chaos_obs_freq_03[:,1,:],axis=1),color='green')
    
# for i in range(num_iter):
#     plt.plot(rmse_l96_chaos_obs_freq_04[:,0,0],rmse_l96_chaos_obs_freq_04[:,1,i],color='red',alpha=0.3)
plt.plot(rmse_l96_chaos_obs_freq_04[:,0,0],np.mean(rmse_l96_chaos_obs_freq_04[:,1,:],axis=1),color='red')

# for i in range(num_iter):
#     plt.plot(rmse_l96_chaos_obs_freq_05[:,0,0],rmse_l96_chaos_obs_freq_05[:,1,i],color='m',alpha=0.3)
plt.plot(rmse_l96_chaos_obs_freq_05[:,0,0],np.mean(rmse_l96_chaos_obs_freq_05[:,1,:],axis=1),color='m')
    
# for i in range(num_iter):
#     plt.plot(rmse_l96_chaos_obs_freq_06[:,0,0],rmse_l96_chaos_obs_freq_06[:,1,i],color='k',alpha=0.3)
plt.plot(rmse_l96_chaos_obs_freq_06[:,0,0],np.mean(rmse_l96_chaos_obs_freq_06[:,1,:],axis=1),color='k')
   
# for i in range(num_iter):
#     plt.plot(rmse_l96_chaos_obs_freq_07[:,0,0],rmse_l96_chaos_obs_freq_07[:,1,i],color='brown',alpha=0.3)
plt.plot(rmse_l96_chaos_obs_freq_07[:,0,0],np.mean(rmse_l96_chaos_obs_freq_07[:,1,:],axis=1),color='brown')
  
    
    
plt.ylim(0,3.0)
plt.xlim(10,55)
# Out:
# (10.0, 55.0)

# %% [markdown]
# # AGSM

# %% [markdown]
# # Periodic

# %%
folder_periodic_agsm='/home/hamed/Data Assimilation Methods/agsm/lorenz_96/periodic_obs_freq/results_rmse/'

num_iter=10
num_tsteps_01=4949
num_tsteps_02=4939
num_tsteps_03=4949
num_tsteps_04=4899
num_tsteps_05=4799
num_tsteps_06=4699
num_tsteps_07=4499

obs_freq_periodic_01=1
obs_freq_periodic_02=2
obs_freq_periodic_03=3
obs_freq_periodic_04=4
obs_freq_periodic_05=5
obs_freq_periodic_06=6
obs_freq_periodic_07=7

rmse_l96_periodic_obs_freq_01=np.zeros((num_tsteps_01,2,num_iter))
rmse_l96_periodic_obs_freq_02=np.zeros((num_tsteps_02,2,num_iter))
rmse_l96_periodic_obs_freq_03=np.zeros((num_tsteps_03,2,num_iter))
rmse_l96_periodic_obs_freq_04=np.zeros((num_tsteps_04,2,num_iter))
rmse_l96_periodic_obs_freq_05=np.zeros((num_tsteps_05,2,num_iter))
rmse_l96_periodic_obs_freq_06=np.zeros((num_tsteps_06,2,num_iter))
rmse_l96_periodic_obs_freq_07=np.zeros((num_tsteps_07,2,num_iter))

for i in range(num_iter):
    
    filename_periodic_agsm_obs_freq_01=os.path.join(folder_periodic_agsm,'rmse_l96_periodic_obs_freq_'+str(obs_freq_periodic_01).zfill(2)+'_run_'+str(i+1).zfill(2)+'.txt')
    filename_periodic_agsm_obs_freq_02=os.path.join(folder_periodic_agsm,'rmse_l96_periodic_obs_freq_'+str(obs_freq_periodic_02).zfill(2)+'_run_'+str(i+1).zfill(2)+'.txt')
    filename_periodic_agsm_obs_freq_03=os.path.join(folder_periodic_agsm,'rmse_l96_periodic_obs_freq_'+str(obs_freq_periodic_03).zfill(2)+'_run_'+str(i+1).zfill(2)+'.txt')
    filename_periodic_agsm_obs_freq_04=os.path.join(folder_periodic_agsm,'rmse_l96_periodic_obs_freq_'+str(obs_freq_periodic_04).zfill(2)+'_run_'+str(i+1).zfill(2)+'.txt')
    filename_periodic_agsm_obs_freq_05=os.path.join(folder_periodic_agsm,'rmse_l96_periodic_obs_freq_'+str(obs_freq_periodic_05).zfill(2)+'_run_'+str(i+1).zfill(2)+'.txt')
    filename_periodic_agsm_obs_freq_06=os.path.join(folder_periodic_agsm,'rmse_l96_periodic_obs_freq_'+str(obs_freq_periodic_06).zfill(2)+'_run_'+str(i+1).zfill(2)+'.txt')
    filename_periodic_agsm_obs_freq_07=os.path.join(folder_periodic_agsm,'rmse_l96_periodic_obs_freq_'+str(obs_freq_periodic_07).zfill(2)+'_run_'+str(i+1).zfill(2)+'.txt')
    
    rmse_l96_periodic_obs_freq_01[:,:,i]=np.genfromtxt(filename_periodic_agsm_obs_freq_01)
    rmse_l96_periodic_obs_freq_02[:,:,i]=np.genfromtxt(filename_periodic_agsm_obs_freq_02)
    rmse_l96_periodic_obs_freq_03[:,:,i]=np.genfromtxt(filename_periodic_agsm_obs_freq_03)
    rmse_l96_periodic_obs_freq_04[:,:,i]=np.genfromtxt(filename_periodic_agsm_obs_freq_04)
    rmse_l96_periodic_obs_freq_05[:,:,i]=np.genfromtxt(filename_periodic_agsm_obs_freq_05)
    rmse_l96_periodic_obs_freq_06[:,:,i]=np.genfromtxt(filename_periodic_agsm_obs_freq_06)
    rmse_l96_periodic_obs_freq_07[:,:,i]=np.genfromtxt(filename_periodic_agsm_obs_freq_07)
    
    
#     rmse_l96_periodic_obs_freq_01.append(rmse_l96_periodic_01)
#     rmse_l96_periodic_obs_freq_02.append(rmse_l96_periodic_02)
#     rmse_l96_periodic_obs_freq_05.append(rmse_l96_periodic_05)

# %%
fig=plt.figure(figsize=(20,10))

# for i in range(num_iter):
#     plt.plot(rmse_l96_periodic_obs_freq_01[:,0,0],rmse_l96_periodic_obs_freq_01[:,1,i],color='gray',alpha=0.3)
plt.plot(rmse_l96_periodic_obs_freq_01[:,0,0],np.mean(rmse_l96_periodic_obs_freq_01[:,1,:],axis=1),color='gray')

# for i in range(num_iter):
#     plt.plot(rmse_l96_periodic_obs_freq_02[:,0,0],rmse_l96_periodic_obs_freq_02[:,1,i],color='blue',alpha=0.3)
plt.plot(rmse_l96_periodic_obs_freq_02[:,0,0],np.mean(rmse_l96_periodic_obs_freq_02[:,1,:],axis=1),color='blue')
    
# for i in range(num_iter):
#     plt.plot(rmse_l96_periodic_obs_freq_03[:,0,0],rmse_l96_periodic_obs_freq_03[:,1,i],color='green',alpha=0.3)
plt.plot(rmse_l96_periodic_obs_freq_03[:,0,0],np.mean(rmse_l96_periodic_obs_freq_03[:,1,:],axis=1),color='green')
    
# for i in range(num_iter):
#     plt.plot(rmse_l96_periodic_obs_freq_04[:,0,0],rmse_l96_periodic_obs_freq_04[:,1,i],color='red',alpha=0.3)
plt.plot(rmse_l96_periodic_obs_freq_04[:,0,0],np.mean(rmse_l96_periodic_obs_freq_04[:,1,:],axis=1),color='red')

# for i in range(num_iter):
#     plt.plot(rmse_l96_periodic_obs_freq_05[:,0,0],rmse_l96_periodic_obs_freq_05[:,1,i],color='m',alpha=0.3)
plt.plot(rmse_l96_periodic_obs_freq_05[:,0,0],np.mean(rmse_l96_periodic_obs_freq_05[:,1,:],axis=1),color='m')
    
# for i in range(num_iter):
#     plt.plot(rmse_l96_periodic_obs_freq_06[:,0,0],rmse_l96_periodic_obs_freq_06[:,1,i],color='k',alpha=0.3)
plt.plot(rmse_l96_periodic_obs_freq_06[:,0,0],np.mean(rmse_l96_periodic_obs_freq_06[:,1,:],axis=1),color='k')
   
# for i in range(num_iter):
#     plt.plot(rmse_l96_periodic_obs_freq_07[:,0,0],rmse_l96_periodic_obs_freq_07[:,1,i],color='brown',alpha=0.3)
plt.plot(rmse_l96_periodic_obs_freq_07[:,0,0],np.mean(rmse_l96_periodic_obs_freq_07[:,1,:],axis=1),color='brown')
  
    
plt.ylim(0,3.0)    
# plt.ylim(0,1.0)
plt.xlim(10,55)
# Out:
# (10.0, 55.0)

# %% [markdown]
# # Chaos

# %%
folder_chaos_agsm='/home/hamed/Data Assimilation Methods/agsm/lorenz_96/chaos_obs_freq/results_rmse/'

num_iter=10
num_tsteps_01=4949
num_tsteps_02=4939
num_tsteps_03=4949
num_tsteps_04=4899
num_tsteps_05=4799
num_tsteps_06=4699
num_tsteps_07=4499

obs_freq_chaos_01=1
obs_freq_chaos_02=2
obs_freq_chaos_03=3
obs_freq_chaos_04=4
obs_freq_chaos_05=5
obs_freq_chaos_06=6
obs_freq_chaos_07=7

rmse_l96_chaos_obs_freq_01=np.zeros((num_tsteps_01,2,num_iter))
rmse_l96_chaos_obs_freq_02=np.zeros((num_tsteps_02,2,num_iter))
rmse_l96_chaos_obs_freq_03=np.zeros((num_tsteps_03,2,num_iter))
rmse_l96_chaos_obs_freq_04=np.zeros((num_tsteps_04,2,num_iter))
rmse_l96_chaos_obs_freq_05=np.zeros((num_tsteps_05,2,num_iter))
rmse_l96_chaos_obs_freq_06=np.zeros((num_tsteps_06,2,num_iter))
rmse_l96_chaos_obs_freq_07=np.zeros((num_tsteps_07,2,num_iter))

for i in range(num_iter):
    
    filename_chaos_agsm_obs_freq_01=os.path.join(folder_chaos_agsm,'rmse_l96_chaotic_obs_freq_'+str(obs_freq_chaos_01).zfill(2)+'_run_'+str(i+1).zfill(2)+'.txt')
    filename_chaos_agsm_obs_freq_02=os.path.join(folder_chaos_agsm,'rmse_l96_chaotic_obs_freq_'+str(obs_freq_chaos_02).zfill(2)+'_run_'+str(i+1).zfill(2)+'.txt')
    filename_chaos_agsm_obs_freq_03=os.path.join(folder_chaos_agsm,'rmse_l96_chaotic_obs_freq_'+str(obs_freq_chaos_03).zfill(2)+'_run_'+str(i+1).zfill(2)+'.txt')
    filename_chaos_agsm_obs_freq_04=os.path.join(folder_chaos_agsm,'rmse_l96_chaotic_obs_freq_'+str(obs_freq_chaos_04).zfill(2)+'_run_'+str(i+1).zfill(2)+'.txt')
    filename_chaos_agsm_obs_freq_05=os.path.join(folder_chaos_agsm,'rmse_l96_chaotic_obs_freq_'+str(obs_freq_chaos_05).zfill(2)+'_run_'+str(i+1).zfill(2)+'.txt')
    filename_chaos_agsm_obs_freq_06=os.path.join(folder_chaos_agsm,'rmse_l96_chaotic_obs_freq_'+str(obs_freq_chaos_06).zfill(2)+'_run_'+str(i+1).zfill(2)+'.txt')
    filename_chaos_agsm_obs_freq_07=os.path.join(folder_chaos_agsm,'rmse_l96_chaotic_obs_freq_'+str(obs_freq_chaos_07).zfill(2)+'_run_'+str(i+1).zfill(2)+'.txt')
    
    rmse_l96_chaos_obs_freq_01[:,:,i]=np.genfromtxt(filename_chaos_agsm_obs_freq_01)
    rmse_l96_chaos_obs_freq_02[:,:,i]=np.genfromtxt(filename_chaos_agsm_obs_freq_02)
    rmse_l96_chaos_obs_freq_03[:,:,i]=np.genfromtxt(filename_chaos_agsm_obs_freq_03)
    rmse_l96_chaos_obs_freq_04[:,:,i]=np.genfromtxt(filename_chaos_agsm_obs_freq_04)
    rmse_l96_chaos_obs_freq_05[:,:,i]=np.genfromtxt(filename_chaos_agsm_obs_freq_05)
    rmse_l96_chaos_obs_freq_06[:,:,i]=np.genfromtxt(filename_chaos_agsm_obs_freq_06)
    rmse_l96_chaos_obs_freq_07[:,:,i]=np.genfromtxt(filename_chaos_agsm_obs_freq_07)
    
    
#     rmse_l96_chaos_obs_freq_01.append(rmse_l96_chaos_01)
#     rmse_l96_chaos_obs_freq_02.append(rmse_l96_chaos_02)
#     rmse_l96_chaos_obs_freq_05.append(rmse_l96_chaos_05)

# %%
fig=plt.figure(figsize=(20,10))

for i in range(num_iter):
    plt.plot(rmse_l96_chaos_obs_freq_01[:,0,0],rmse_l96_chaos_obs_freq_01[:,1,i],color='lightgray',alpha=0.3)
plt.plot(rmse_l96_chaos_obs_freq_01[:,0,0],np.mean(rmse_l96_chaos_obs_freq_01[:,1,:],axis=1),color='gray')

for i in range(num_iter):
    plt.plot(rmse_l96_chaos_obs_freq_02[:,0,0],rmse_l96_chaos_obs_freq_02[:,1,i],color='lightblue',alpha=0.3)
plt.plot(rmse_l96_chaos_obs_freq_02[:,0,0],np.mean(rmse_l96_chaos_obs_freq_02[:,1,:],axis=1),color='blue')
    
for i in range(num_iter):
    plt.plot(rmse_l96_chaos_obs_freq_03[:,0,0],rmse_l96_chaos_obs_freq_03[:,1,i],color='lightgreen',alpha=0.3)
plt.plot(rmse_l96_chaos_obs_freq_03[:,0,0],np.mean(rmse_l96_chaos_obs_freq_03[:,1,:],axis=1),color='green')
    
# for i in range(num_iter):
#     plt.plot(rmse_l96_chaos_obs_freq_04[:,0,0],rmse_l96_chaos_obs_freq_04[:,1,i],color='red',alpha=0.3)
plt.plot(rmse_l96_chaos_obs_freq_04[:,0,0],np.mean(rmse_l96_chaos_obs_freq_04[:,1,:],axis=1),color='red')

# for i in range(num_iter):
#     plt.plot(rmse_l96_chaos_obs_freq_05[:,0,0],rmse_l96_chaos_obs_freq_05[:,1,i],color='m',alpha=0.3)
plt.plot(rmse_l96_chaos_obs_freq_05[:,0,0],np.mean(rmse_l96_chaos_obs_freq_05[:,1,:],axis=1),color='m')
    
# for i in range(num_iter):
#     plt.plot(rmse_l96_chaos_obs_freq_06[:,0,0],rmse_l96_chaos_obs_freq_06[:,1,i],color='k',alpha=0.3)
plt.plot(rmse_l96_chaos_obs_freq_06[:,0,0],np.mean(rmse_l96_chaos_obs_freq_06[:,1,:],axis=1),color='k')
   
for i in range(num_iter):
    plt.plot(rmse_l96_chaos_obs_freq_07[:,0,0],rmse_l96_chaos_obs_freq_07[:,1,i],color='brown',alpha=0.3)
plt.plot(rmse_l96_chaos_obs_freq_07[:,0,0],np.mean(rmse_l96_chaos_obs_freq_07[:,1,:],axis=1),color='brown')
  
    
    
plt.ylim(0,3.0)
# plt.xlim(10,55)
plt.xlim(10,30)
# Out:
# (10.0, 30.0)
